# %% [markdown]
# # Excercise - 1
#
# ## World Food Facts

# %%
import pandas as pd
import numpy as np

# %%
food = pd.read_csv('C:/Users/DELL/RFA/dataset/en.openfoodfacts.org.products.tsv',sep='\t',low_memory=False)

# %%
# setting display limit to max

pd.set_option('display.max_columns',None)

# %%
food
# Out:
#                  code                                                url  \
# 0       0000000003087  http://world-en.openfoodfacts.org/product/0000...
# 1       0000000004530  http://world-en.openfoodfacts.org/product/0000...
# 2       0000000004559  http://world-en.openfoodfacts.org/product/0000...
# 3       0000000016087  http://world-en.openfoodfacts.org/product/0000...
# 4       0000000016094  http://world-en.openfoodfacts.org/product/0000...
# ...               ...                                                ...
# 356022       99567453  http://world-en.openfoodfacts.org/product/9956...
# 356023  9970229501521  http://world-en.openfoodfacts.org/product/9970...
# 356024  9977471758307  http://world-en.openfoodfacts.org/product/9977...
# 356025  9980282863788  http://world-en.openfoodfacts.org/product/9980...
# 356026   999990026839  http://world-en.openfoodfacts.org/product/9999...
#
#                            creator   created_t      created_datetime  \
# ...

# %% [markdown]
# # See the first 5 entries

# %%
food.head(5)
# Out:
#             code                                                url  \
# 0  0000000003087  http://world-en.openfoodfacts.org/product/0000...
# 1  0000000004530  http://world-en.openfoodfacts.org/product/0000...
# 2  0000000004559  http://world-en.openfoodfacts.org/product/0000...
# 3  0000000016087  http://world-en.openfoodfacts.org/product/0000...
# 4  0000000016094  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#   last_modified_t last_modified_datetime                    product_name  \
# 0      1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# ...

# %% [markdown]
# # What is the number of observations in the dataset?

# %%
len(food)

#print(food_df.shape[0])
# Out:
# 356027

# %% [markdown]
# # What is the number of columns in the dataset?

# %%
len(food.columns)

#food_df.shape[1]

food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 356027 entries, 0 to 356026
# Columns: 163 entries, code to water-hardness_100g
# dtypes: float64(107), object(56)
# memory usage: 442.8+ MB

# %% [markdown]
# # Print the name of all the columns.

# %%
col_name = [x for x in food.columns]

col_name

#food.columns
#col = list(food.columns)
# Out:
# ['code',
#  'url',
#  'creator',
#  'created_t',
#  'created_datetime',
#  'last_modified_t',
#  'last_modified_datetime',
#  'product_name',
#  'generic_name',
#  'quantity',
#  'packaging',
#  'packaging_tags',
#  'brands',
#  'brands_tags',
#  'categories',
#  'categories_tags',
#  'categories_en',
#  'origins',
#  'origins_tags',
#  'manufacturing_places',
#  'manufacturing_places_tags',
#  'labels',
#  'labels_tags',
#  'labels_en',
#  'emb_codes',
#  'emb_codes_tags',
#  'first_packaging_code_geo',
#  'cities',
#  'cities_tags',
#  'purchase_places',
#  'stores',
#  'countries',
#  'countries_tags',
#  'countries_en',
#  'ingredients_text',
#  'allergens',
#  'allergens_en',
#  'traces',
#  'traces_tags',
#  'traces_en',
#  'serving_size',
#  'no_nutriments',
#  'additives_n',
#  'additives',
#  'additives_tags',
#  'additives_en',
#  'ingredients_from_palm_oil_n',
#  'ingredients_from_palm_oil',
#  'ingredients_from_palm_oil_tags',
# ...

# %% [markdown]
# # What is the name of 105th column?

# %%
food.columns[104]

#food.columns.get_loc('-glucose_100g') ## just to confirm
# Out:
# '-glucose_100g'

# %% [markdown]
# # What is the type of the observations of the 105th column?

# %%
print(food['-glucose_100g'].dtypes)

#food['-glucose_100g']
#food.dtypes['-glucose_100g']
# Out:
# float64

# %% [markdown]
# # How is the dataset indexed?

# %%
food.index
# Out:
# RangeIndex(start=0, stop=356027, step=1)

# %% [markdown]
# # What is the product name of the 19th observation?

# %%
product_name = food.loc[18,'product_name']

product_name

#food.values[18][7]
# Out:
# 'Lotus Organic Brown Jasmine Rice'
